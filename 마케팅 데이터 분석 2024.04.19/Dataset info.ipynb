# %% [markdown]
# >order DataFrame
#
# - **파일명**: `order_9968.csv`
# - **데이터 크기**: 데이터 로우 수 × 11 열
# - **형식**: CSV (콤마로 구분된 값)
#
# 칼럼 설명
#
# | 칼럼명           | 데이터 타입 | 설명                                         |
# |------------------|-------------|---------------------------------------------|
# | `id`             | 정수        | 고유 식별자                           |
# | `type`           | 문자열      | 주문 유형      |
# | `state`          | 문자열      | 주문 상태                   |
# | `name`           | 문자열      | 강의명                                       |
# | `created_at`     | 문자열      | 주문 날짜                               |
# | `updated_at`     | 문자열      | 주문 정보 최종 업데이트 날짜                  |
# | `customer_id`    | 정수        | 고객 ID                          |
# | `list_price`     | 실수        | 상품 정가                                  |
# | `sale_price`     | 실수        | 상품 판매가                                |
# | `discount_price` | 실수        | 할인 금액                                    |
# | `tax_free_price` | 실수        | 비과세 금액                                  |

# %% [markdown]
# >course DataFrame
#
# - **파일명**: `course-9968.csv`
# - **데이터 크기**: 722 행 × 10 열
# - **형식**: CSV (콤마로 구분된 값)
#
# 칼럼 설명
#
# | 칼럼명               | 데이터 타입 | 설명                                                |
# |----------------------|-------------|----------------------------------------------------|
# | `id`                 | 정수        | 고유 식별자                                  |
# | `type`               | 문자열      | 과정의 타입 (예: 온라인, 오프라인)                   |
# | `state`              | 문자열      | 과정의 상태 (예: 진행중, 완료)                       |
# | `created_at`         | 문자열      | 생성 날짜                                      |
# | `updated_at`         | 문자열      | 업데이트 날짜                         |
# | `title`              | 문자열      | 강의명                                           |
# | `description`        | 문자열      | 부가 설명                                           |
# | `close_at`           | 문자열      | 폐강된 강의                                      |
# | `total_class_hours`  | 정수        | 총 수업 시간                                        |
# | `keywords`           | 문자열      | 과정 관련 키워드 (예: 프로그래밍, 데이터 사이언스)    |

# %% [markdown]
# >customer DataFrame
#
# - **파일명**: `customer-9968.xlsx`
# - **데이터 크기**: 123,013 행 × 9 열
# - **형식**: Excel (XLSX)
#
# 칼럼 설명
#
# | 칼럼명         | 데이터 타입 | 설명                                 |
# |----------------|-------------|--------------------------------------|
# | `id`           | 정수        | 고객 식별자                   |
# | `type`         | 문자열      | 고객의 유형       |
# | `state`        | 문자열      | 고객의 상태      |
# | `created_at`   | 문자열      | 고객 정보 생성 날짜                   |
# | `updated_at`   | 문자열      | 고객 정보 최종 업데이트 날짜          |
# | `user_id`      | 정수        | 고객의 고유 ID                      |
# | `name`         | 문자열      | 고객의 닉네임                           |
# | `phone`        | 문자열      | 고객의 전화번호                       |
# | `email`        | 문자열      | 고객의 이메일 주소                    |

# %% [markdown]
# >refund DataFrame
#
# - **파일명**: `refund-9968.csv`
# - **데이터 크기**: 12,674 행 × 9 열
# - **형식**: CSV (콤마로 구분된 값)
#
# 칼럼 설명
#
# | 칼럼명           | 데이터 타입 | 설명                                    |
# |------------------|-------------|----------------------------------------|
# | `id`             | 정수        | 고유 식별자                    |
# | `type`           | 문자열      | 환불 유형             |
# | `state`          | 문자열      | 환불 처리 상태        |
# | `created_at`     | 문자열      | 환불 요청 생성 날짜                       |
# | `updated_at`     | 문자열      | 환불 정보 최종 업데이트 날짜              |
# | `user_id`        | 정수        | 환불 요청 사용자 ID                     |
# | `course_id`      | 정수        | 환불 요청 강의 ID                       |
# | `amount`         | 실수        | 환불 금액                                 |
# | `tax_free_amount`| 실수        | 최종 금액

# %% [markdown]
# >user DataFrame
#
# - **파일명**: `user-9968.csv`
# - **데이터 크기**: 122,989 행 × 7 열
# - **형식**: CSV (콤마로 구분된 값)
#
# 칼럼 설명
#
# | 칼럼명         | 데이터 타입 | 설명                                   |
# |----------------|-------------|---------------------------------------|
# | `id`           | 정수        | 고유 식별자                   |
# | `type`         | 문자열      | 사용자 유형   |
# | `state`        | 문자열      | 사용자 상태           |
# | `created_at`   | 문자열      | 사용자 계정 생성 날짜                   |
# | `updated_at`   | 문자열      | 사용자 정보 최종 업데이트 날짜          |
# | `last_login_at`| 문자열      | 마지막 로그인 시간               |
# | `username`     | 문자열      | 사용자명                               |
